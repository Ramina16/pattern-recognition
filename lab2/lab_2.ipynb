# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from functions import Kozinec, data_shuffle, plot_decision_regions, check_eig

# %%
with open('train_01.json', 'r') as f:
    data = json.load(f)
    print(data)
df = pd.DataFrame(data['inside']+data['outside'], columns=['x1', 'x2'])
with open('train_02.json', 'r') as f:
    data1 = json.load(f)
df1 = pd.DataFrame(data1['inside']+data1['outside'], columns=['x1', 'x2'])

# %%
df['target'] = [1 for i in data['inside']] + [0 for i in data['outside']]
df1['target'] = [1 for i in data1['inside']] + [0 for i in data1['outside']]

# %%
df
# Out:
#           x1        x2  target
# 0   0.729520  0.728634       1
# 1   0.826506  0.940316       1
# 2   0.602314  0.489100       1
# 3   0.792430  0.972460       1
# 4   0.373906  0.380795       1
# 5   0.521383  0.701165       1
# 6   0.579949  0.860210       1
# 7   0.447271  0.232087       1
# 8   0.826693  0.970862       1
# 9   0.209609  0.079489       1
# 10  0.338326  0.411363       1
# 11  0.683833  0.900314       1
# 12  0.397408  0.446432       1
# 13  0.261937  0.207272       1
# 14  0.846590  0.126805       0
# 15  0.116710  0.852347       0
# 16  0.893944  0.204420       0
# 17  0.196516  0.756340       0
# 18  0.762462  0.176754       0
# 19  0.864621  0.428951       0
# 20  0.708638  0.171807       0
# 21  0.073085  0.706869       0
# 22  0.742972  0.196811       0
# 23  0.685063  0.011556       0
# 24  0.055998  0.514718       0
# 25  0.964555  0.450044       0
# 26  0.250763  0.884590       0
# 27  0.128520  0.798343       0
# 28  0.018173  0.845386       0

# %%
df1
# Out:
#           x1        x2  target
# 0   0.672175  0.184493       1
# 1  -0.042170  0.496807       1
# 2   0.036909  0.231968       1
# 3  -0.185166 -0.163244       1
# 4   0.199091 -0.207021       1
# 5  -0.262389  0.446881       1
# 6   0.619550  0.039807       1
# 7   0.441863 -0.003950       1
# 8   0.280229 -0.352572       1
# 9   0.074489 -0.497364       1
# 10  0.642289 -0.003541       1
# 11  0.039664  0.348849       1
# 12  0.482525  0.559799       1
# 13 -0.124801  0.363961       1
# 14  0.458646  0.503909       1
# 15  0.495335  0.298197       1
# 16  0.210670 -0.264776       1
# 17 -0.165189  0.312122       1
# 18  0.230463 -0.013246       1
# 19  0.828194 -0.483710       0
# 20 -0.785869 -0.236199       0
# 21 -0.710011  0.414047       0
# 22 -0.466424  0.761995       0
# 23 -0.457970  0.661598       0
# 24  0.598318 -0.822166       0
# 25  0.822132 -0.157712       0
# 26 -0.495373 -0.771143       0
# 27 -0.742236  0.718222       0
# 28 -0.637788  0.566488       0
# ...

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['x1'][:14], df['x2'][:14], color='red', label='class 1')
plt.scatter(df['x1'][14:], df['x2'][14:], color='blue', label='class 0')
plt.legend(loc='best')

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df1['x1'][:19], df1['x2'][:19], color='red', label='class 1')
plt.scatter(df1['x1'][19:], df1['x2'][19:], color='blue', label='class 0')
plt.legend(loc='best')

# %%
df_shuffle, X, y = data_shuffle(df)
df1_shuffle, X1, y1 = data_shuffle(df1)

# %%
X1_new = X1.values
y1_new = y1.values

# %%
X_new = X.values
y_new = y.values

# %%
koz_test = Kozinec(n_iter=15)
koz_test1 = Kozinec(n_iter=2)

# %%
koz_test.fit(X_new, y_new)
koz_test1.fit(X1_new, y1_new)

# %%
plt.figure(figsize=(8,5))
plot_decision_regions(X1_new, y1_new, koz_test1)
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(8,5))
plot_decision_regions(X_new, y_new, koz_test)
plt.legend(loc='best')
plt.show()
